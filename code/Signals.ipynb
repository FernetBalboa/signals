# %%
from __future__ import print_function, division

# %matplotlib inline

import thinkdsp
import thinkplot
#import matplotlib.pyplot as plt

import numpy as np
import random

from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets
from IPython.display import display

# %%
#Experimentos:
#    1. Framerate
#    2. Low pass/ high pass / band_stop
#    3. Caracterizacion de LTIs
#    4. Limpieza de sonido de ambiente ?

# %%
#1 - Framerate

#Low framerate
oh = thinkdsp.read_wave('audios/oh normal.wav')
display(oh.make_audio()) #Original
ohLow = thinkdsp.Wave(oh.ys[0:len(yeah.ys)], oh.ts, oh.framerate / 2)
display(ohLow.make_audio()) # Lower framerate

#High framerate
yeah = thinkdsp.read_wave('audios/yeah normal.wav')
display(yeah.make_audio()) #Original
yeahHigh = thinkdsp.Wave(yeah.ys, yeah.ts, yeah.framerate * 2)
display(yeahHigh.make_audio()) # Higher framerate
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 2 - Filters

# %%
# 3 - LTI 

miedo = thinkdsp.read_wave('audios/miedo normal.wav')
clap = thinkdsp.read_wave('audios/clap_reverb.wav')

clap.truncate(len(miedo))
display(miedo.make_audio())
display(clap.make_audio())

mix = (clap.make_spectrum() * miedo.make_spectrum()).make_wave()
mix.apodize()
mix.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 4 - Limpieza de ruido ambiente

# %%
yeahSpec = yeah.make_spectrum()
# Mover todo lo que esta entre 0 y 5000 

yeahSpec.hs = np.roll(yeahSpec.hs, 500)
#yeahSpec.high_pass(5000)

yeahSpec.plot()

highPitch = yeahSpec.make_wave()
display(highPitch.make_audio())

#ohSpect.low_pass(5000) 



real = ohSpec.real
imag = ohSpec.imag

# module = # For sqrt(real[i] ** 2 + imag[i] ** 2)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
